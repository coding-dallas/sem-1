# %%
from scipy.io import wavfile
import librosa
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.api as sm
from scipy.fftpack import fft,fftfreq
from IPython.display import Audio

# %%
voiced='C:/Users/kesav/OneDrive/Desktop/Academics/speech signal processing/Assignment-3/o1.wav'
voiceData,Voicefs=librosa.load(voiced,sr=8000)

# %%
plt.specgram(voiceData,Fs=Voicefs,cmap='Spectral')
# Out:
# (array([[4.66023398e-11, 4.97277218e-13, 2.30732182e-09, ...,
#          1.68738230e-11, 4.42502743e-11, 1.72353987e-11],
#         [2.99101162e-09, 1.17528969e-08, 7.52354766e-09, ...,
#          2.71444676e-10, 8.14237007e-10, 6.03270045e-11],
#         [9.44787738e-09, 3.61855250e-10, 8.26512516e-08, ...,
#          1.42974312e-08, 2.16151756e-08, 3.01258642e-08],
#         ...,
#         [2.53961922e-12, 1.25911581e-13, 1.09725147e-12, ...,
#          6.07452528e-16, 4.75465860e-15, 8.46541291e-17],
#         [1.33179306e-14, 1.56466079e-13, 3.92164209e-14, ...,
#          5.33563037e-16, 3.56454793e-15, 7.77511388e-17],
#         [5.70704456e-15, 4.00311894e-14, 1.92519255e-14, ...,
#          5.46210703e-17, 1.67081703e-15, 2.58669843e-17]]),
#  array([   0.  ,   31.25,   62.5 ,   93.75,  125.  ,  156.25,  187.5 ,
#          218.75,  250.  ,  281.25,  312.5 ,  343.75,  375.  ,  406.25,
#          437.5 ,  468.75,  500.  ,  531.25,  562.5 ,  593.75,  625.  ,
# ...

# %%
unvoiced='C:/Users/kesav/OneDrive/Desktop/Academics/speech signal processing/Assignment-3/unvoiced.wav'
unvoiceData,unvoicefs=librosa.load(unvoiced,sr=8000)

# %%
plt.specgram(unvoiceData,Fs=unvoicefs)
# Out:
# (array([[1.85339365e-10, 7.75728029e-10, 1.55504214e-09, ...,
#          7.10798993e-12, 3.16573675e-10, 9.91105743e-10],
#         [2.38299933e-09, 2.65063487e-09, 2.25388769e-08, ...,
#          1.34652376e-12, 1.26152555e-09, 2.90732413e-09],
#         [2.60070762e-08, 1.17185142e-07, 3.28260027e-07, ...,
#          2.55334218e-08, 1.04953829e-08, 5.49051334e-08],
#         ...,
#         [3.66961334e-15, 2.07486739e-13, 7.52208414e-13, ...,
#          1.18313884e-12, 7.83634514e-14, 4.07632360e-14],
#         [5.22665962e-15, 7.83632130e-14, 6.12557648e-13, ...,
#          5.93511408e-13, 1.11744367e-13, 4.38526051e-14],
#         [2.53060436e-15, 3.30572443e-14, 2.58700541e-13, ...,
#          2.59563865e-13, 1.78790262e-14, 1.70089106e-14]]),
#  array([   0.  ,   31.25,   62.5 ,   93.75,  125.  ,  156.25,  187.5 ,
#          218.75,  250.  ,  281.25,  312.5 ,  343.75,  375.  ,  406.25,
#          437.5 ,  468.75,  500.  ,  531.25,  562.5 ,  593.75,  625.  ,
# ...
