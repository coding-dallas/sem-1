# %%
from scipy.io import wavfile
import librosa
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.api as sm
from scipy.fftpack import fft

# %%
fileName='C:/Users/kesav/OneDrive/Desktop/Academics/speech signal processing/Assignment-3/vowel utter.wav'
data,fs=librosa.load(fileName,sr=16000)
length = data.shape[0] / fs
fs
# Out:
# 16000

# %%
plt.specgram(data,Fs=fs,NFFT=512,window=np.hamming(512),noverlap=256,cmap='jet_r')
plt.colorbar()
