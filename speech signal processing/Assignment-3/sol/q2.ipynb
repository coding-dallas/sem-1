# %%
from scipy.io import wavfile
import librosa
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.api as sm
from scipy.fftpack import fft
import librosa.display
from IPython.display import Audio
from python_speech_features import mfcc
import warnings
warnings.filterwarnings("ignore")

# %%
fileName='C:/Users/kesav/OneDrive/Desktop/Academics/speech signal processing/Assignment-3/name1.wav'
(fs,data)=wavfile.read(fileName)

# %%
MF=mfcc(data,fs,numcep=13,nfilt=26, preemph=0.97)

# %%
plt.figure(figsize=(20,10))
plt.xlabel('time')
plt.ylabel('MFCC coefficients')
plt.imshow(np.transpose(MF),aspect='auto')
plt.colorbar()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       1 DB = librosa.amplitude_to_db(data, ref=np.max)
# ----> 2 librosa.display.specshow(DB, sr=fs, hop_length=hop_length, x_axis='time', y_axis='log');
#       3 plt.colorbar(format='%+2.0f dB')
#
# NameError: name 'hop_length' is not defined
