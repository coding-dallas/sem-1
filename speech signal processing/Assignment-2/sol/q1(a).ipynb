# %%
from scipy.io import wavfile
import numpy as np
from matplotlib import pyplot as plt

fileName='C:/Users/kesav/OneDrive/Desktop/Academics/speech signal processing/Assignment-2/H_MKB.wav'
samplerate,amp=wavfile.read(fileName)
length = amp.shape[0] / samplerate

time = np.linspace(0, length, amp.shape[0])
plt.plot(time,amp)
plt.xlabel('time')
plt.ylabel('amplitude')
plt.title('Time domain plot')
# Out:
# Text(0.5, 1.0, 'Time domain plot')
